# %%
import os 
doc_list = []
with os.scandir("c:/Users/Semih/Documents/GitHub/VocabCam/WordList") as tarama:
    for belge in tarama:
        if belge.name.endswith("txt"):
            doc_list.append(belge.name)
doc_list
# Out:
# ['Computer Reading Son.txt', 'Computer Reading.txt']

# %%
for i in doc_list:
    with open("Computer Reading.txt","r+",encoding="utf-8") as file:
    content= file.readlines()
    parag=  file.read()
    

    untitled=""
    for i in content:
        if(i.isupper()==True or (i.istitle()==True)):
            untitled += " "
        else:
            untitled += i + " "
    with open("Computer Reading Son.txt","a",encoding="utf-8") as file1:
        for i in untitled:
            file1.write(i)

# %%
import string 
from nltk.tokenize import sent_tokenize
with open("Computer Reading Son.txt","r",encoding="utf-8") as file: 
    contents=file.read()
    content_clear =contents.replace("\n","")
    content_clear = content_clear.replace("/n","")
    
    def punctuation_clear(text):
        result = ""
        for i in text:
            if( i not in string.punctuation or i == " " ):
                result+= i 
            else:
                result+= ""
        return result
    def punctuation_clear_list(text):
        result = ""
        for i in text:
            for a in i:
                if( a not in string.punctuation or a == "." or a == " " ):
                    result+= a 
            
        return result
    content_clears = punctuation_clear(content_clear)
    content_split_sentence = punctuation_clear_list(content_clear).split(".")
    content_word_split= set(content_clears.split())
    word_list= list()
    say = 0
    for i in content_word_split:
        if(len(i)>=3):
            word_list.append(i)
            say+=1
    print(content_word_split)
# Out:
# {'There', 'education', 'free', 'form', 'uploading', 'logged', 'edutainment', 'aluminium', 'doctors', 'music', 'range', 'Microsoft', 'mathematical', 'multipurpose', 'videoconferencing', 'menus', 'Internet', 'boards', 'producing', '3’', 'displayed', 'Worid', 'PC', 'without', 'input', 'mentioned', 'like', 'only', 'They', 'digital', 'microchip', 'single', 'graphic', 'creating', 'IRC', 'capital', 'home', 'referred', 'Web', 'access', 'boardrooms', 'have', 'normally', 'processes', 'animation', 'on', 'name', 'smart', 'password', 'CDs', 'applications', 'applied', 'peripherals', 'fridges', 'most', 'such', 'company', 'built', 'this', 'An', 'storage', 'used', 'desktop', 'developed', 'program', 'other', 'cannot', 'use', 'W', 'people', 'Networks', 'fo', '‘connectivity’', 'example', 'time', 'compact', 'called', 'Common', 'world', 'what', 'available', 'treatment', 'purposes', 'ie', 'store', 'parts', 'photographs', 'television', 'office', 'Chat', 'gradually', 'drivers’', 'done', 'one', 'circuit', 'remove', 'searched', 'sending', 'select', 'memory', 'experts', 'sound', 'to', 'processed', 'printing', 'moving', 'future', 'device', 'decide', 'term', 'chip', 'types', 'greetings', 'according', 'diagnose', 'realtime', 'internet', 'note', 'As', 'video', 'threedimensional', 'Net', 'around', 'they', 'browsing', 'distance', 'balances', 'so', 'cards', 'their', 'externally', 'calculating', 'button', 'items', 'ina', 'are', 'known', 'together', 'mail', 'uses', 'more', 'painting', 'enclosed', 'account', 'fixed', 'provide', 'CDROMs', 'learning', 'formulae', 'down', 'magnetic', 'by', 'Word', 'receiving', 'all', 'can', 'expansion', 'documents', 'in', 'taking', 'Services', 'best', 'is', 'actually', 'standards', 'enable', 'software', 'The', 'service', 'Medical', 'attached', 'Antivirus', '‘think’', 'connection', 'themselves', 'small', 'PCs', 'hard', 'a', 'able', 'purpose', 'related', 'found', 'inserted', 'compatible', 'Not', 'personal', 'instructions', 'be', 'household', 'Computer', 'plastic', 'choices', 'Electronics', 'an', 'computers', 'between', 'washing', 'features', 'mouse', 'although', 'Various', 'devices', 'webpage', 'user', 'File', 'of', 'attach', 'these', 'typewriter', 'laid', 'and', 'This', 'combination', 'share', 'records', 'entertainment', 'situations', 'same', 'multimedia', 'set', 'becoming', 'browser', 'main', 'telecommute', 'programs', 'commonly', 'incorporated', 'readydrawn', 'different', 'website', 'screen', 'possible', 'read', 'signals', 'clipart', 'superhighway', 'case', 'simple', 'plugged', 'writing', 'security', 'graphics', 'server', 'files', 'communicating', 'Dogpile', 'AskJeeves', 'copying', 'required', 'desk', 'harmful', 'services', 'camera', 'editing', 'laser', 'spreadsheets', 'Wide', 'webpages', 'for', 'slots', 'added', 'communicate', 'resources', 'influenced', 'forms', 'interlinked', 'working', 'give', 'health', 'email', '‘Pets', 'throughout', 'as', 'newest', 'transferring', 'Protocol', 'person', 'machines', 'allows', 'tools', 'at', 'designed', 'variety', 'One', 'wide', 'monitor', 'A', 'sometimes', 'detect', 'Connecting', 'reproduce', 'provides', 'equipment', 'relevant', 'WWW', 'that', 'disk', 'users', 'electronic', 'plugging', 'computer', 'reading', 'output', 'not', 'touch', 'audio', 'from', 'come', 'lists', 'coated', 'system', 'integrated', 'attachments', 'clicking', 'handheld', 'inputting', 'user’s', 'network', 'packaged', 'bank', 'part', 'Those', 'package', 'help', 'Relay', 'Unlike', 'cars', 'usually', 'style', 'networks', 'very', 'scanning', 'eg', 'including', 'phones', 'out', 'illness', 'interface', 'being', 'wordprocessors', 'simply', 'storing', 'pictures', 'systems', 'paper', 'material', 'How', 'common', 'Cat’', 'keyboard', 'images', 'vacuumsealed', 'licences', 'Devices', 'cameras', 'printer', 'often', 'communication', 'process', 'chat', 'do', 'well', 'viruses', 'powerful', 'selling', 'interfaces', 'find', 'expert', 'classrooms', 'special', 'delay', 'light', 'carried', 'chip’', 'etc', 'Some', 'or', 'disks', 'looks', 'Transfer', 's ...

# %%
sentence_list_last= list()
for a in word_list:
    x=0
    for i in content_split_sentence:
        sentence = i.split()
        for j in sentence:
            if a==j:
                sentence_list_last.append(i)
                x+=1
            if x==1:
                break
        if x==1:
            break
            
content_clear_split_last = list()

    
say = 0
for i in sentence_list_last:
    say+=1
print(say)
# Out:
# 410

# %%
from nltk.stem.snowball import SnowballStemmer
stem_list=[]

for i in word_list:
    stemmer = SnowballStemmer("english")
    stem_list.append(stemmer.stem(i))
#stem_set = set(stem_list)
#stem_list = list(stem_set)
a=  0
for i in stem_list:
    a+=1
print(a)
# Out:
# 410

# %%
from googletrans import Translator
translator = Translator()
ceviri_list= list()
for i in word_list:
    translation = translator.translate(i,dest = 'tr')
    ceviri_list.append(translation.text)

# %%
import pandas as pd
dict = {"Raw":word_list,"Root":stem_list,"Translation":ceviri_list,"Sentence":sentence_list_last}
df= pd.DataFrame(dict)
df.to_csv("Computer Reading Translate.csv")
df
# Out:
#            Raw     Root    Translation  \
# 0        There    there          Orası
# 1    education     educ         Eğitim
# 2         free     free         Bedava
# 3         form     form          biçim
# 4    uploading   upload        yükleme
# ..         ...      ...            ...
# 405   hardware  hardwar        donanım
# 406    enables    enabl  etkinleştirir
# 407       vast     vast       büyüklük
# 408       each     each       her biri
# 409       text     text          Metin
#
#                                               Sentence
# 0      There is a range of sizes and types of computer
# 1     This enables computer systems to be used for ...
# 2     An Internet system designed to provide free i...
# 3     Connecting computers together to form a netwo...
# 4     Note that copying data from a larger server s...
# ..                                                 ...
# 405   The equipment is known as  the hardware and t...
# 406   This enables computers to be built into other...
# 407   An Internet system designed to provide free i...
# 408   video files attached to simple email text mes...
# 409   A multimedia computer can process different f...
#
# [410 rows x 4 columns]

# %%
import os 
import string 
from nltk.stem.snowball import SnowballStemmer
from googletrans import Translator
import pandas as pd


doc_list = list()
with os.scandir("c:/Users/Semih/Documents/GitHub/VocabCam/WordList") as tarama:
    for belge in tarama:
        if belge.name.endswith("txt"):
            doc_list.append(belge.name)

for i in doc_list:

    with open(i,"r+",encoding="utf-8") as file:
        content= file.readlines()
        parag=  file.read()
    untitled=""
    for a in content:
        if(a.isupper()==True or (a.istitle()==True)):
            untitled += " "
        else:
            untitled += a + " "
    with open("Son "+i,"a",encoding="utf-8") as file1:
        for b in untitled:
            file1.write(b)
    with open("Son "+i,"r",encoding="utf-8") as file: 
        contents=file.read()
        content_clear =contents.replace("\n","")
        content_clear = content_clear.replace("/n","")
    
        def punctuation_clear(text):
            result = ""
            for i in text:
                if( i not in string.punctuation or i == " " ):
                    result+= i 
                else:
                    result+= ""
            return result
        def punctuation_clear_list(text):
            result = ""
            for i in text:
                for a in i:
                    if( a not in string.punctuation or a == "." or a == " " ):
                        result+= a 
            
            return result
        content_clears = punctuation_clear(content_clear)
        content_split_sentence = punctuation_clear_list(content_clear).split(".")
        content_word_split= set(content_clears.split())
        word_list= list()
        say = 0
        for i in content_word_split:
            if(len(i)>=3):
                word_list.append(i)
    
    sentence_list_last= list()
    for a in word_list:
        x=0
        for i in content_split_sentence:
            sentence = i.split()
            for j in sentence:
                if a==j:
                    sentence_list_last.append(i)
                    x+=1
                if x==1:
                    break
            if x==1:
                break
            
    content_clear_split_last = list()
    
    stem_list=[]

    for i in word_list:
        stemmer = SnowballStemmer("english")
        stem_list.append(stemmer.stem(i))
    
    translator = Translator()
    ceviri_list= list()
    for i in word_list:
        translation = translator.translate(i,dest = 'tr')
        ceviri_list.append(translation.text)    
    
    dict = {"Raw":word_list,"Root":stem_list,"Translation":ceviri_list,"Sentence":sentence_list_last}
    df= pd.DataFrame(dict)
    df.to_csv(i+".csv")

# %%
df
# Out:
#               Raw      Root   Translation  \
# 0            desk      desk          sıra
# 1            time      time         zaman
# 2            disk      disk          disk
# 3            mail      mail         posta
# 4           while     while          süre
# ..            ...       ...           ...
# 405      internet  internet      internet
# 406           IRC       irc           IRC
# 407  mathematical  mathemat  matematiksel
# 408      licences    licenc        lisans
# 409       writing     write          yazı
#
#                                               Sentence
# 0     Those designed for use by one person at a tim...
# 1     Those designed for use by one person at a tim...
# 2     video files attached to simple email text mes...
# 3     Various communication services are available ...
# 4     without any delay while the users are logged ...
# ..                                                 ...
# 405       Networks connected together form an internet
# 406   Various communication services are available ...
# 407   Common applications programs include wordproc...
# 408   smart cards which are able to store informati...
# 409   CDROMs are storage devices that use laser lig...
#
# [410 rows x 4 columns]
