# %%
    with open("Computer Reading.txt","r+",encoding="utf-8") as file:
        content= file.readlines()
        parag=  file.read()
    

        untitled=""
        for i in content:
            if(i.isupper()==True or (i.istitle()==True)):
                untitled += " "
            else:
                untitled += i + " "
    with open("Computer Reading Son.txt","a",encoding="utf-8") as file1:
        for i in untitled:
            file1.write(i)

# %%
import string 
from nltk.tokenize import sent_tokenize
with open("Computer Reading Son.txt","r",encoding="utf-8") as file: 
    contents=file.read()
    content_clear =contents.replace("\n","")
    content_clear = content_clear.replace("/n","")
    
    def punctuation_clear(text):
        result = ""
        for i in text:
            if( i not in string.punctuation or i == " " ):
                result+= i 
            else:
                result+= ""
        return result
    def punctuation_clear_list(text):
        result = ""
        for i in text:
            for a in i:
                if( a not in string.punctuation or a == "." or a == " " ):
                    result+= a 
            
        return result
    content_clears = punctuation_clear(content_clear)
    content_split_sentence = punctuation_clear_list(content_clear).split(".")
    content_word_split= set(content_clears.split())
    word_list= list()
    say = 0
    for i in content_word_split:
        if(len(i)>=3):
            word_list.append(i)

# %%
sentence_list_last = list()
for a in word_list:
    x=0
    for i in content_split_sentence:
        sentence = i.split()
        for j in sentence:
            if a==j:
                sentence_list_last.append(i)
                x+=1
            if x==1:
                break
        if x==1:
            break
            
content_clear_split_last = list()

    
say = 0
for i in sentence_list_last:
    say+=1
print(say)
# Out:
# 423

# %%
from nltk.stem.snowball import SnowballStemmer
stem_list=[]

for i in word_list:
    stemmer = SnowballStemmer("english")
    stem_list.append(stemmer.stem(i))
#stem_set = set(stem_list)
#stem_list = list(stem_set)
a=  0
for i in stem_list:
    a+=1
print(a)
# Out:
# 423

# %%
from googletrans import Translator
translator = Translator()
ceviri_list= list()
for i in word_list:
    translation = translator.translate(i,dest = 'tr')
    ceviri_list.append(translation.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       3 ceviri_list= list()
#       4 for i in word_list:
# ----> 5     translation = translator.translate(i,dest = 'tr')
#       6     ceviri_list.append(translation.text)
#
# File ~\anaconda3\lib\site-packages\googletrans\client.py:182, in Translator.translate(self, text, dest, src, **kwargs)
#     179     return result
#     181 origin = text
# --> 182 data = self._translate(text, dest, src, kwargs)
#     184 # this code will be updated when the format is changed.
#     185 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File ~\anaconda3\lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
#      77 def _translate(self, text, dest, src, override):
# ---> 78     token = self.token_acquirer.do(text)
#      79     params = utils.build_params(query=text, src=src, dest=dest,
#      80                                 token=token, override=override)
#      82     url = urls.TRANSLATE.format(host=self._pick_service_url())
#
# File ~\anaconda3\lib\site-packages\googletrans\gtoken.py:194, in TokenAcquirer.do(self, text)
#     193 def do(self, text):
# --> 194     self._update()
#     195     tk = self.acquire(text)
#     196     return tk
#
# File ~\anaconda3\lib\site-packages\googletrans\gtoken.py:62, in TokenAcquirer._update(self)
#      59     return
#      61 # this will be the same as python code after stripping out a reserved word 'var'
# ---> 62 code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      63 # unescape special ascii characters such like a \x3d(=)
#      64 code = code.encode().decode('unicode-escape')
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
from nltk.corpus import state_union
import nltk
from nltk.tokenize import PunktSentenceTokenizer
code_list = list()
for i in word_list:
        words = nltk.word_tokenize(i)
        tagged = nltk.pos_tag(words)
        code_list.append(tagged[0][1])

# %%
import pandas as pd
dict = {"Code:":code_list,"Raw":word_list,"Root":stem_list,"Translation":ceviri_list,"Sentence":sentence_list_last}
df= pd.DataFrame(dict)
df.to_csv("Computer Reading Translate.csv")

# %%
df
# Out:
#     Code:           Raw      Root  Translation  \
# 0      VB         allow     allow  izin vermek
# 1      NN          hear      hear       duymak
# 2     VBG       editing      edit    düzenleme
# 3     NNS     standards  standard  standartlar
# 4      NN      distance   distanc       mesafe
# ..    ...           ...       ...          ...
# 405   NNS  applications    applic      başvuru
# 406    IN         while     while         süre
# 407    NN         style     style         stil
# 408   NNS       choices     choic     seçimler
# 409    NN      Protocol  protocol     Protokol
#
#                                               Sentence
# 0     Some operating systems have graphical user in...
# 1     video files attached to simple email text mes...
# 2     Common applications programs include wordproc...
# 3     Those designed for use by one person at a tim...
# 4     video files attached to simple email text mes...
# ..                                                 ...
# 405   A special set of programs called an operating...
# 406   without any delay while the users are logged ...
# 407   The main device for inputting the data is a t...
# 408   Some operating systems have graphical user in...
# 409   An Internet service called FTP File Transfer ...
#
# [410 rows x 5 columns]

# %%
import pandas as pd 
df = pd.read_csv("Computer Reading Translate.csv")
df = df.drop(columns="Unnamed: 0")
df.to_pickle("ComputerReading.pkl")

# %%
df.to_json("ComputerReading.json")

# %%
dataf = pd.read_json("ComputerReading.json")

# %%
dataf
# Out:
#     Code:           Raw      Root  Translation  \
# 0      VB         allow     allow  izin vermek
# 1      NN          hear      hear       duymak
# 2     VBG       editing      edit    düzenleme
# 3     NNS     standards  standard  standartlar
# 4      NN      distance   distanc       mesafe
# ..    ...           ...       ...          ...
# 405   NNS  applications    applic      başvuru
# 406    IN         while     while         süre
# 407    NN         style     style         stil
# 408   NNS       choices     choic     seçimler
# 409    NN      Protocol  protocol     Protokol
#
#                                               Sentence
# 0     Some operating systems have graphical user in...
# 1     video files attached to simple email text mes...
# 2     Common applications programs include wordproc...
# 3     Those designed for use by one person at a tim...
# 4     video files attached to simple email text mes...
# ..                                                 ...
# 405   A special set of programs called an operating...
# 406   without any delay while the users are logged ...
# 407   The main device for inputting the data is a t...
# 408   Some operating systems have graphical user in...
# 409   An Internet service called FTP File Transfer ...
#
# [410 rows x 5 columns]

# %%
import os 
import string 
from nltk.stem.snowball import SnowballStemmer
from googletrans import Translator
import pandas as pd


doc_list = []
with os.scandir("c:/Users/Semih/Documents/GitHub/VocabCam/WordList") as tarama:
    for belge in tarama:
        if belge.name.endswith("txt"):
            doc_list.append(belge.name)

for i in doc_list:

    with open(i,"r+",encoding="utf-8") as file:
        content= file.readlines()
        parag=  file.read()
    untitled=""
    for a in content:
        if(a.isupper()==True or (a.istitle()==True)):
            untitled += " "
        else:
            untitled += a + " "
    with open("Son "+i,"a",encoding="utf-8") as file1:
        for b in untitled:
            file1.write(b)
    with open("Son "+i,"r",encoding="utf-8") as file: 
        contents=file.read()
        content_clear =contents.replace("\n","")
        content_clear = content_clear.replace("/n","")
    
        def punctuation_clear(text):
            result = ""
            for i in text:
                if( i not in string.punctuation or i == " " ):
                    result+= i 
                else:
                    result+= ""
            return result
        def punctuation_clear_list(text):
            result = ""
            for i in text:
                for a in i:
                    if( a not in string.punctuation or a == "." or a == " " ):
                        result+= a 
            
            return result
        content_clears = punctuation_clear(content_clear)
        content_split_sentence = punctuation_clear_list(content_clear).split(".")
        content_word_split= set(content_clears.split())
        word_list= list()
        say = 0
        for i in content_word_split:
            if(len(i)>=3):
                word_list.append(i)
    
    sentence_list_last= list()
    for a in word_list:
        x=0
        for i in content_split_sentence:
            sentence = i.split()
            for j in sentence:
                if a==j:
                    sentence_list_last.append(i)
                    x+=1
                if x==1:
                    break
            if x==1:
                break
            
    content_clear_split_last = list()
    
    stem_list=[]

    for i in word_list:
        stemmer = SnowballStemmer("english")
        stem_list.append(stemmer.stem(i))
    
    translator = Translator()
    translate_list= list()
    for i in word_list:
        translation = translator.translate(i,dest = 'tr')
        translate_list.append(translation.text)  
    code_list = list()
    for i in word_list:
        words = nltk.word_tokenize(i)
        tagged = nltk.pos_tag(words)
        code_list.append(tagged)
        
    
    dict = {"Raw":word_list,"Root":stem_list,"Translation":translate_list,"Sentence":sentence_list_last}
    df= pd.DataFrame(dict)
    df.to_csv(i+".csv")

# %%
df
# Out:
#               Raw      Root   Translation  \
# 0            desk      desk          sıra
# 1            time      time         zaman
# 2            disk      disk          disk
# 3            mail      mail         posta
# 4           while     while          süre
# ..            ...       ...           ...
# 405      internet  internet      internet
# 406           IRC       irc           IRC
# 407  mathematical  mathemat  matematiksel
# 408      licences    licenc        lisans
# 409       writing     write          yazı
#
#                                               Sentence
# 0     Those designed for use by one person at a tim...
# 1     Those designed for use by one person at a tim...
# 2     video files attached to simple email text mes...
# 3     Various communication services are available ...
# 4     without any delay while the users are logged ...
# ..                                                 ...
# 405       Networks connected together form an internet
# 406   Various communication services are available ...
# 407   Common applications programs include wordproc...
# 408   smart cards which are able to store informati...
# 409   CDROMs are storage devices that use laser lig...
#
# [410 rows x 4 columns]

# %%
dict = {"Noun"=}
