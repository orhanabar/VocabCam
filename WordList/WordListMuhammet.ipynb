# %%
#DENEME
#Google Translate API için gerekli modul
from googletrans import Translator

# %%
words ="""
A computer is a device that processes data
according to a set of instructions known

as a program. The equipment is known as

the hardware and the programs and data

are the software. A special set of programs,
called an operating system, provides an
interface for the user and allows applications
programs to communicate with the hardware.
Common applications programs include
wordprocessors for creating and editing texts,
spreadsheets for calculating mathematical
formulae and databases for storing data ina
way that allows the data to be sorted and
searched. Anti-virus programs are used to
detect and remove viruses (harmful programs
that can reproduce themselves and attach
themselves to other programs). Some
operating systems have graphical (user)
interfaces that allow the computer user to
select items from menus (lists of choices) and
to start programs using an input device called
a mouse. This is done by pressing a button on
the mouse i.e. clicking the mouse. The main
device for inputting the data is a typewriter-
style keyboard and the output is commonly
displayed on a monitor screen that looks like
a small television screen.

There is a range of sizes and types of
computer. Those designed for use by one
person at a time are known as personal
computers (PCs} although the term PC is
usually only applied to personal computers
that are compatible with the standards laid
down by the company known as IBM

computers include desktop computers (for
use on an office desk) and handheld
computers that can be carried around by the
user. Electronics can be added to desktop
computers by plugging in expansion cards
(electronic circuit boards that can be plugged
into special sockets called expansion slots).

 

 

It is also possible to build all the main parts
of a computer into one electronic integrated
circuit packaged as a single electronic chip
(the common name for a microchip; an
electronic integrated circuit in a small
package) i.e. the ‘computer on a chip’. This
enables computers to be built into other
devices including household devices such as
washing machines and fridges and to be
incorporated into plastic cards i.e. smart
cards, which are able to store information
such as health records, drivers’ licences,
bank balances, etc. Devices that include a
computer circuit are commonly referred to as
smart devices. A multimedia computer can
process different forms of data including
text, graphics, audio (sound), animation and
video. This enables computer systems to be
used for a combination of education and
entertainment, sometimes referred to as
edutainment.

Unlike most machines, computers do not
have a fixed purpose. They are multi-purpose
tools. They can be used in a very wide variety
of situations and are found in a wide range of
systems including security systems, cars and
phones. Advanced systems, known as expert
systems, enable computers to ‘think’ like
experts. Medical expert systems, for example,
can help doctors diagnose an illness and
decide on the best treatment. As computer
systems are developed, they are becoming
more common and are gradually being used
for more and more purposes. How they are
developed, and for what purposes they are
actually used in the future, can be influenced
by computer users. A variety of devices known
as peripherals can be added externally to a
computer. One of the most common
peripherals is a printer used for printing the
computer output (the processed data or
signals that come out of a computer system)


on paper. A digital camera allows
photographs to be input to a computer for
editing.

Not all computer systems are compatible
i.e, they cannot use the same programs and
data. Connecting computers together to form
a network can provide the ‘connectivity’
required to enable computers and software
to communicate and fo share resources.
Networks connected together form an
internet. The connection of networks
throughout the world is known as the Internet
(note that a capital | is used) or, more simply,
the Net. Various communication services are
available on the Internet, including email
(electronic mail) for sending and receiving
text messages and IRC (Internet Relay Chat)
which allows users to communicate using text
messages in real-time i.e. without any delay,
while the users are logged on (connected to a
network system account, normally using a
password) to the system. An Internet service
called FTP (File Transfer Protocol) is used for
transferring data or program files between the
powerful server computers that provide the
network services and the client computers
that use these services e.g. downloading
music files. Note that copying data from a
larger server system to a client is referred to
as downloading and copying from the client
to the server is known as uploading.

One of the newest and most popular
services available on the Internet is the Worid
Wide Web (WWW) which is often simply
referred to as the Web (note the use of the
capital W). The Web contains interlinked
documents called webpages. A set of related
webpages stored together on a server
computer is called a website. Websites, such
as Dogpile and AskJeeves, give the user

 

 

access to special programs called search
engines that are designed to allow the user to
find relevant webpages on the Web. An
Internet system designed to provide free,
interactive access to vast resources for people
all over the world is sometimes referred to as
an information superhighway.

Services such as these allow people to
telecommute (use their computers to stay in
touch with the office while they are working
at home). Computer uses mentioned in this
unit include producing greetings cards;
learning, using three-dimensional graphics
programs called ‘Splat the Cat’ and ‘Pets 3’;
using the Microsoft Word wordprocessing
program including features such as clipart
(ready-drawn graphic images that can be
inserted into documents); communicating on
the Internet using email and chat programs
including the use of email attachments (other
types of files e.g. video files attached to
simple email text messages); distance
learning and videoconferencing (a form of
communication over a network that uses
video cameras so that the people taking part
can see and hear each other); electronic
classrooms or boardrooms; browsing the Web
(moving from webpage to webpage using a
Web browser program); selling, using a
website; painting; scanning pictures;
downloading music and creating CD-ROMs
(compact disk read only memory, commonly
referred to as CDs). CD-ROMs are storage
devices that use laser light for reading and
writing data. The most common storage
device is a hard disk (a set of aluminium
disks coated in a magnetic material and
enclosed in a vacuum-sealed case) used for
storing the operating system and applications
programs as well as the user’s data.
"""

# %%
from googletrans import Translator
#Translate modulünden bir nesne oluşturdum.
translator = Translator()
sentence = words
#Hangi Dilde Çevrileceğini belirlediğimiz satır.
translation = translator.translate(sentence, dest='tr')
#Dönüştürülen dilde ki cümle
print(translation.text)
#Çevrilen Dil
print("Hangi Dilde Çevrildi: ",translation.src)
# Out:
# Bilgisayar, verileri işleyen bir cihazdır
# bilinen bir dizi talimata göre
#
# program olarak. Ekipman olarak bilinir
#
# donanım ve programlar ve veriler
#
# yazılımlardır. Özel bir dizi program,
# işletim sistemi adı verilen bir
# kullanıcı için arayüz ve uygulamalara izin verir
# Donanımla iletişim kurmak için programlar.
# Ortak uygulama programları şunları içerir:
# metinler oluşturmak ve düzenlemek için kelime işlemciler,
# matematiksel hesaplamalar için elektronik tablolar
# veri depolamak için formüller ve veritabanları
# verilerin sıralanmasını sağlayan ve
# arandı. Anti-virüs programları kullanılır
# virüsleri tespit edin ve kaldırın (zararlı programlar
# kendilerini çoğaltabilen ve ekleyebilen
# kendilerini diğer programlara). Bazı
# işletim sistemlerinde grafik (kullanıcı) var
# bilgisayar kullanıcısına izin veren arayüzler
# menülerden öğeleri seçin (seçenek listeleri) ve
# adlı bir giriş aygıtı kullanarak programları başlatmak için
# Bir fare. Bu, üzerindeki bir düğmeye basılarak yapılır.
# fare, yani fareye tıklamak. Ana
# veri girişi için cihaz bir daktilo-
# stil klavye ve çıktı genellikle
# gibi görünen bir monitör ekranında görüntülenir.
# küçük bir televizyon ekranı.
#
# Bir dizi boyut ve tür vardır
# bilgisayar. Tek kişi tarafından kullanılmak üzere tasarlanmış olanlar
# bir seferde kişi kişisel olarak bilinir
# bilgisayarlar (PC'ler}, ancak PC terimi
# genellikle sadece kişisel bilgisayarlara uygulanır
# belirlenen standartlara uygun
# IBM olarak bilinen şirket tarafından
#
# bilgisayarlar masaüstü bilgisayarları içerir (için
# ofis masasında kullanın) ve elde taşınır
# tarafından taşınabilen bilgisayarlar
# kullanıcı. Elektronikler masaüstüne eklenebilir
# genişletme kartlarını takarak bilgisayarlar
# (takılabilen elektronik devre kartları
# genişletme yuvaları adı verilen özel yuvalara).
#
#
#
#
#
# Tüm ana parçaları inşa etmek de mümkündür
# bir bilgisayarın tek bir elektronik entegre
# tek bir elektronik çip olarak paketlenmiş devre
# (bir mikroçipin ortak adı; bir
# küçük bir elektronik entegre devre
# paket) yani 'bir çip üzerindeki bilgisayar'. Bu
# bilgisayarların diğerlerinin içine yerleştirilmesini sağlar
# gibi ev cihazları dahil cihazlar
# çamaşır makineleri ve buzdolapları ve olmak
# plastik kartlara dahil edilmiştir, yani akıllı
# bilgi depolayabilen kartlar
# sağlık kayıtları, ehliyetler gibi
# banka bakiyeleri vb. içeren cihazlar
# bilgisayar devresi genellikle olarak adlandırılır
# akıllı cihazlar. Multimedya bilgisayar olabilir
# dahil olmak üzere farklı veri biçimlerini işlemek
# metin, grafik, ses (ses), animasyon ve
# video. Bu, bilgisayar sistemlerinin
# eğitim kombinasyonu için kullanılır ve
# eğlence, bazen olarak anılacaktır
# eğitim.
#
# Çoğu makinenin aksine, bilgisayarlar
# sabit bir amacı vardır. Onlar çok amaçlı
# aletler. Çok geniş bir yelpazede kullanılabilirler
# durumların ve geniş bir yelpazede bulunur
# güvenlik sistemleri, arabalar ve
# telefonlar. Uzman olarak bilinen gelişmiş sistemler
# sistemler, bilgisayarların olduğu gibi 'düşünmesini' sağlar
# uzmanlar. Tıbbi uzman sistemler, örneğin,
# doktorların bir hastalığı teşhis etmesine yardımcı olabilir ve
# en iyi tedaviye karar verin. bilgisayar olarak
# sistemler geliştiriliyor,
# daha yaygın ve yavaş yavaş kullanılıyor
# giderek daha fazla amaç için. onlar nasıl
# geliştirilmiş ve hangi amaçlarla
# aslında gelecekte kullanılan, etkilenebilir
# bilgisayar kullanıcıları tarafından Bilinen çeşitli cihazlar
# çevre birimleri harici olarak eklenebilir
# bilgisayar. En yaygın olanlardan biri
# çevre birimleri yazdırmak için kullanılan bir yazıcıdır.
# bilgisayar çıktısı (işlenen veriler veya
# bir bilgisayar sisteminden gelen sinyaller)
#
#
# kağıtta. Bir dijital kamera izin verir
# bilgisayara girilecek fotoğraflar
# düzenleme.
#
# Tüm bilgisayar sistemleri uyumlu değildir
# yani aynı programları kullanamazlar ve
# veri. Bilgisayarları oluşturmak için birbirine bağlama
# bir ağ "bağlantı" sağlayabilir
# bilgisayarları ve yazılımları etkinleştirmek için gerekli
# iletişim kurmak ve kaynakları paylaşmak için.
# Birbirine bağlanan ağlar bir
# internet. ağların bağlanması
# tüm dünyada internet olarak bilinir
# (bir büyük harfin | kullanıldığını unutmayın) veya daha basit olarak,
# ağ. Çeşitli iletişim hizmetleri
# e-posta dahil olmak üzere internette mevcut
# (elektronik posta) göndermek ve almak için
# metin mesajları ve IRC (İnternet Aktarmalı Sohbet)
# kullanıcıların metin kullanarak iletişim kurmasını sağlayan
# mesajları gerçek zamanlı olarak, yani herhangi bir gecikme olmaksızın,
# kullanıcılar oturum açarken (bir
# ağ sistemi hesabı, normalde bir
# şifre) sisteme girin. İnternet hizmeti
# FTP (Dosya Aktarım Protokolü) adı verilen
# arasında veri veya program dosyalarının aktarılması
# sağlayan güçlü sunucu bilgisayarlardır.
# ağ hizmetleri ve istemci bilgisayarlar
# bu hizmetleri kullananlar, ör. indiriliyor
# müzik dosyaları. Verileri bir
# bir istemciye daha büyük sunucu sistemi denir
# istemciden indirme ve kopyalama olarak
# sunucuya yükleme olarak bilinir.
#
# En yeni ve en popüler olanlardan biri
# İnternette mevcut olan hizmetler Dünya'dır.
# Genellikle basit olan Geniş Ağ (WWW)
# Web olarak anılacaktır (kullanımına dikkat edin)
# sermaye W). Web, birbirine bağlı
# Web sayfaları adı verilen belgeler. Bir dizi ilgili
# bir sunucuda birlikte depolanan web sayfaları
# Bilgisayara web sitesi denir. Web siteleri, bu tür
# Dogpile ve AskJeeves olarak, kullanıcıya
#
#
#
#
#
# arama adı verilen özel programlara erişim
# kullanıcıya izin verecek şekilde tasarlanmış motorlar
# Web'de ilgili web sayfalarını bulun. Bir
# Ücretsiz sağlamak için tasarlanmış internet sistemi,
# insanlar için geniş kaynaklara etkileşimli erişim
# tüm dünyada bazen denir
# bir bilgi otoyolu.
#
# Bu gibi hizmetler, insanların
# telekomünikasyon (içinde kalmak için bilgisayarlarını kullanın)
# onlar çalışırken ofise dokunmak
# evde). Bu bölümde belirtilen bilgisayar kullanımları
# birim, tebrik kartları üretmeyi içerir;
# üç boyutlu grafikler kullanarak öğrenme
# 'Splat the Cat' ve 'Pets 3' adlı programlar;
# Microsoft Word kelime işlemcisini kullanma
# küçük resim gibi özellikler içeren program
# (olabilecek hazır çizilmiş grafik görüntüler
# belgelere eklenir); iletişim kurmak
# e-posta ve sohbet programlarını kullanarak İnternet
# e-posta eklerinin kullanımı dahil (diğer
# dosya türleri örn. ekli video dosyaları
# basit e-posta metin mesajları); mesafe
# öğrenme ve video konferans (bir tür
# kullanan bir ağ üzerinden iletişim
# video kameralar, böylece katılan insanlar
# birbirini görebilir ve duyabilir); elektronik
# derslikler veya toplantı odaları; Web'de gezinme
# (bir web sayfasından web sayfasına geçiş
# Web tarayıcı programı); satan, kullanan
# İnternet sitesi; tablo; resimleri taramak;
# müzik indirme ve CD-ROM oluşturma
# (kompakt disk salt okunur bellek, genellikle
# CD olarak anılacaktır). CD-ROM'lar depolama
# Okumak için lazer ışığı kullanan cihazlar ve
# veri yazma. En yaygın depolama
# cihaz bir sabit disktir (bir dizi alüminyum
# manyetik malzeme ile kaplanmış diskler ve
# vakumla kapatılmış bir kutu içinde) için kullanılır
# işletim sistemini ve uygulamaları depolamak
# programların yanı sıra kullanıcı verileri.
# Hangi Dilde Çevrildi:  en

# %%
#PyDictionary kütüphanesini ekledim.
from PyDictionary import PyDictionary
#PyDictionary modulünden bir nesne oluşturdum.
dictionary=PyDictionary()
#İngilizce anlamını almak istediğimiz kelimeyi girdik.
definition = dictionary.meaning("pencil")
#Döngülerle verilen sonuçları alt alta maddeler halinde sıraladım.
for key,value in definition.items():
    print(key + '\n\n')

    for values in value:
        print(f'- {values}\n\n')
# Out:
# Noun
#
#
# - a thin cylindrical pointed writing implement; a rod of marking substance encased in wood
#
#
# - graphite (or a similar substance
#
#
# - a figure formed by a set of straight lines or light rays meeting at a point
#
#
# - a cosmetic in a long thin stick; designed to be applied to a particular part of the face
#
#
# Verb
#
#
# - write, draw, or trace with a pencil

# %%
from PyDictionary import PyDictionary
dictionary=PyDictionary()
definition=dictionary.meaning("pencil")['Noun'][0]
print("Noun: ",definition)
# Out:
# Noun:  a thin cylindrical pointed writing implement; a rod of marking substance encased in wood
